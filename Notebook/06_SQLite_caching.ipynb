# %%
from langchain_core.globals import set_llm_cache
from langchain_community.cache import SQLiteCache

set_llm_cache(SQLiteCache(database_path=".langchain.db"))

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3.2:latest", temperature=0.3)

response = llm.invoke("write a 1000 word essay on the importance of AI in modern society")

print(response.content)
# Out:
# The Importance of Artificial Intelligence (AI) in Modern Society
#
# Artificial intelligence (AI) has become an integral part of modern society, transforming various aspects of our lives and revolutionizing the way we live, work, and interact with one another. From enhancing productivity and efficiency to improving healthcare outcomes and facilitating communication, AI has proven to be a game-changer in numerous industries and domains. In this essay, we will explore the significance of AI in modern society, its benefits, and challenges.
#
# One of the most significant advantages of AI is its ability to automate repetitive and mundane tasks, freeing up human resources for more complex and creative endeavors. For instance, AI-powered chatbots have become increasingly popular in customer service, allowing companies to provide 24/7 support and respond to queries in a timely manner. Similarly, AI-driven tools have streamlined various administrative tasks, such as data entry and bookkeeping, enabling businesses to focus on high-value activities that drive growth and innovation.
#
# Another critical aspect of AI is its potential to enhance productivity and efficiency. By leveraging machine learning algorithms and natural language processing (NLP), AI systems can analyze vast amounts of data, identify patterns, and make predictions with unprecedented accuracy. This has significant implications for industries such as finance, healthcare, and transportation, where data-driven insights can inform decision-making and drive business outcomes.
#
# AI also plays a vital role in improving healthcare outcomes. By analyzing medical records, genomic data, and other health-related information, AI systems can identify potential health risks, detect diseases at an early stage, and provide personalized treatment recommendations. For example, AI-powered diagnostic tools have been shown to improve accuracy rates for conditions such as cancer, diabetes, and cardiovascular disease.
#
# Furthermore, AI has the potential to revolutionize education and learning. AI-powered adaptive learning systems can tailor educational content to individual students' needs, abilities, and learning styles, providing a more personalized and effective learning experience. Additionally, AI-driven tools have enabled teachers to create customized lesson plans, track student progress, and identify areas where students require additional support.
#
# In addition to its practical applications, AI also has significant social implications. For instance, AI-powered virtual assistants, such as Siri, Alexa, and Google Assistant, have become ubiquitous in our daily lives, enabling us to manage our schedules, set reminders, and access information with ease. Moreover, AI-driven tools have enabled people with disabilities to communicate more effectively, interact with others, and participate fully in society.
#
# However, the increasing reliance on AI also raises concerns about job displacement, bias, and accountability. As AI systems become more sophisticated, they are increasingly capable of performing tasks that were previously exclusive to humans. This has significant implications for workers who may find themselves replaced by machines or automated processes. Moreover, AI systems can perpetuate biases and prejudices if they are trained on biased data sets, leading to discriminatory outcomes.
#
# Moreover, the increasing use of AI also raises concerns about accountability and transparency. As AI systems become more complex, it becomes increasingly difficult to understand how decisions are made and who is responsible for errors or malfunctions. This has significant implications for industries such as finance, healthcare, and transportation, where AI-driven systems can have far-reaching consequences.
#
# To address these challenges, it is essential that we develop a comprehensive framework for the development and deployment of AI systems. This includes investing in research and development to improve AI's transparency, accountability, and fairness. Moreover, policymakers must establish regulations and guidelines to ensure that AI systems are developed and deployed responsibly, prioritizing human well-being and dignity.
#
# In conclusion, AI has become an integral part of modern society, transforming various aspects of our lives and revolutionizing the way we live, work, and interact with one another. While there are significant benefits to AI, including enhanced productivity, improved healthcare outcomes, and facilitated communication, there are also challenges that must be addressed, such as job displacement, bias, and accountability.
#
# To harness the full potential of AI while minimizing its risks, it is essential that we prioritize responsible development and deployment practices. This includes investing in research and development to improve AI's transparency, accountability, and fairness, as well as establishing regulations and guidelines to ensure that AI systems are developed and deployed responsibly.
#
# Ultimately, the future of AI holds much promise for humanity. By embracing AI as a tool for enhancing productivity, improving healthcare outcomes, and facilitating communication, we can unlock new opportunities for growth, innovation, and progress. However, it is essential that we approach AI with caution, prioritizing human well-being and dignity above all else.
#
# References:
#
# 1. "The Future of Artificial Intelligence: Opportunities and Challenges" by the World Economic Forum.
# 2. "Artificial Intelligence in Healthcare: A Review of the Current State and Future Directions" by the Journal of Medical Systems.
# 3. "The Impact of Artificial Intelligence on Education: A Systematic Review" by the Journal of Educational Psychology.
#
# Note: The references provided are for illustrative purposes only and may not be up-to-date or accurate at the time of reading.
# c:\Users\yasho\OneDrive\Desktop\Agent_Evaluation\.venv\Lib\site-packages\langchain_community\cache.py:265: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit list of allowed classes (or 'messages' for untrusted input that contains only chat messages) to suppress this warning.
#   return [loads(row[0]) for row in rows]
