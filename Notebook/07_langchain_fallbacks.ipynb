# %%
import logging
import litellm

# Hide LiteLLM fallback errors, warnings, and debug logs
litellm.set_verbose = False
litellm.suppress_debug_info = True
litellm.disable_streaming_logging = True

logging.getLogger("LiteLLM").setLevel(logging.CRITICAL)
logging.getLogger("litellm").setLevel(logging.CRITICAL)

# %%
from langchain_litellm import ChatLiteLLM
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Primary model
primary = ChatLiteLLM(model="gpt-x")

# Fallbacks (any LangChain-compatible model)
fallback_1 = ChatLiteLLM(model="gpt-4o-mini", temperature=0.2)
fallback_2 = ChatLiteLLM(model="ollama/llama3.2:latest", temperature=0.2)

# LangChain's .with_fallbacks() chains them together
robust_llm = primary.with_fallbacks([fallback_1, fallback_2])

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert AI engineer."),
    ("user", "{question}")
])

chain = prompt | robust_llm | StrOutputParser()

result = chain.invoke(
    {"question": "What are the top 3 benefits of an LLM Gateway?"})
print(result)
# Out:
# As an expert AI engineer, I'd be happy to share with you the top 3 benefits of an LLM (Large Language Model) Gateway:
#
# **1. Improved Security and Data Protection**
#
# An LLM Gateway provides a secure layer between the user's application or system and the underlying LLM model. This ensures that sensitive data is not exposed to unauthorized access, reducing the risk of data breaches and cyber attacks. By implementing an LLM Gateway, you can control who has access to your LLM model, ensuring that only authorized users can interact with it.
#
# **2. Enhanced Scalability and Performance**
#
# An LLM Gateway allows for better scalability and performance by offloading the processing load from the underlying LLM model. This means that the gateway can handle a large volume of requests without compromising the performance of the LLM model. Additionally, an LLM Gateway can be designed to distribute the workload across multiple instances, ensuring high availability and reduced latency.
#
# **3. Simplified Integration and Management**
#
# An LLM Gateway provides a standardized interface for integrating with various applications or systems, making it easier to manage and maintain your LLM model. By providing a single entry point for accessing the LLM model, an LLM Gateway simplifies the integration process, reduces complexity, and minimizes the risk of errors. This also enables easier monitoring, logging, and troubleshooting of the LLM model.
#
# By implementing an LLM Gateway, you can unlock these benefits and create a more secure, scalable, and manageable LLM solution for your applications or systems.
